# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Bangladesh_Rain_dataset.csv")

# %%
df
# Out:
#           tem  Month  Year       rain
# 0     16.9760      1  1901   18.53560
# 1     19.9026      2  1901   16.25480
# 2     24.3158      3  1901   70.79810
# 3     28.1834      4  1901   66.16160
# 4     27.8892      5  1901  267.21500
# ...       ...    ...   ...        ...
# 1375  28.0642      8  2015  512.12700
# 1376  28.1230      9  2015  353.86900
# 1377  26.8624     10  2015   81.59940
# 1378  23.1842     11  2015    4.60815
# 1379  18.7124     12  2015    5.97798
#
# [1380 rows x 4 columns]

# %%
df.Year.unique()[-10:]
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])

# %%
Month_avg = df.groupby('Month')['rain'].mean()
print(Month_avg)
# Out:
# Month
# 1       7.766269
# 2      19.630137
# 3      44.178570
# 4     152.983283
# 5     272.104374
# 6     474.458357
# 7     516.814200
# 8     439.298765
# 9     306.252435
# 10    166.905410
# 11     32.622033
# 12      6.291346
# Name: rain, dtype: float64

# %%
plt.figure(figsize=(10,8))
plt.bar(Month_avg.index,Month_avg)
plt.xlabel('Month')
plt.ylabel('Avg Rainfall')
plt.title('monthly avg rainfall')
plt.show()

# %% [markdown]
# Here, we can see that july month has the most rainfall and january and december month has the lowest rainfall.

# %%
plt.pie(Month_avg,labels =Month_avg.index,autopct='%1.1f%%')
plt.title('monthly avg rainfall')
plt.show()

# %% [markdown]
# Here, we can see that july(21.2%) month has the most rainfall and january(0.9%) and december(0.9%) month has the lowest rainfall

# %%
df.Year.unique()[-20:]
# Out:
# array([1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])

# %%
tem_avg = df.groupby('Month')['tem'].mean()
print(tem_avg)
# Out:
# Month
# 1     18.269363
# 2     20.543337
# 3     24.981827
# 4     27.575446
# 5     28.082954
# 6     28.139225
# 7     27.993544
# 8     28.043764
# 9     28.007675
# 10    26.742418
# 11    23.098166
# 12    19.316831
# Name: tem, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(average_temp_by_month['Month'], average_temp_by_month['tem'])
plt.xlabel('Month')
plt.ylabel('Average Temperature')
plt.title('Average Temperature by Month Over the Last 20 Years')
plt.show()
max_temp_month = average_temp_by_month.loc[average_temp_by_month['tem'].idxmax(), 'Month']
print(f"The month with the highest average temperature is {max_temp_month}.")
# Out:
# The month with the highest average temperature is 5.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Bangladesh_Rain_dataset.csv')

last_15_years = df[df['Year'] >= (df['Year'].max() - 15)]
last_15_years = last_15_years.drop(columns=['Year'])

last_15_years.boxplot()

plt.show()

# %% [markdown]
# Here, we two outliers in this box-plot.

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Yes, year is increasing the temperature is increasing also .
